# %%
# https://www.geeksforgeeks.org/univariate-bivariate-and-multivariate-data-and-its-analysis/

# %%
import pandas as pd

# %%
# First, I'll load the dataset to examine its structure and check for missing values. Then, I'll display some basic statistics to summarize the data.

data = pd.read_csv("C:/Users/SkillCircle/Desktop/Projects/Cap 2 Loan Approval EDA-20240730T150203Z-001/Cap 2 Loan Approval EDA/loan_sanction_test.csv")

# %%
data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
print("First few rows of the dataset: ")
data.head()
# Out:
# First few rows of the dataset:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# ...

# %%
# Check for missing values
print("\nMissing values in each column:")
print(data.isnull().sum())
# Out:
# Missing values in each column:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ### Data Exploration
#
# 1. **Dataset Structure**:
#    - The dataset contains 367 entries and 12 columns.
#    - The data types include integers, floats, and objects (categorical data).
#
# 2. **Missing Values**:
#    - Columns like `Gender`, `Dependents`, `Self_Employed`, `LoanAmount`, `Loan_Amount_Term`, and `Credit_History` have missing values.
#    - We will need to handle these missing values during data preprocessing.
#
# 3. **Basic Statistics**:
#    - Numeric columns such as `ApplicantIncome`, `CoapplicantIncome`, `LoanAmount`, `Loan_Amount_Term`, and `Credit_History` provide essential information about income distribution, loan amounts, and credit history.
#    - The `ApplicantIncome` varies significantly, ranging from 0 to 72,529, which suggests a high income disparity among applicants.
#    - The average loan amount is around 136, with a standard deviation of 61, indicating moderate variability.
#
# Next steps:
# - Handle missing values using appropriate strategies (mean/mode imputation or dropping rows).
# - Perform data visualization to gain isualization tasks?

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %% [markdown]
# ### 1. **Gender (11 missing values)**:
#    - **Approach**: Impute with the most frequent value (mode).
#    - **Reasoning**: Gender is a categorical variable, and imputing with the mode (most common value) is a common approach when the missing data is relatively small. This maintains the distribution of the data without introducing too much bias.
#    - **Code**:
#      ```python
#      data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)
#      ```
#
# ### 2. **Dependents (10 missing values)**:
#    - **Approach**: Impute with the most frequent value (mode).
#    - **Reasoning**: Like Gender, Dependents is a categorical variable. Imputing with the mode is a simple yet effective method, especially when the number of missing values is low.
#    - **Code**:
#      ```python
#      data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)
#      ```
#
# ### 3. **Self_Employed (23 missing values)**:
#    - **Approach**: Impute with the most frequent value (mode).
#    - **Reasoning**: Similar to Gender and Dependents, Self_Employed is a categorical variable. Since the percentage of missing values is still low, imputing with the mode minimizes bias.
#    - **Code**:
#      ```python
#      data['Self_Employed'].fillna(data['Self_Employed'].mode()[0], inplace=True)
#      ```
#
# ### 4. **LoanAmount (5 missing values)**:
#    - **Approach**: Impute with the median value.
#    - **Reasoning**: LoanAmount is a numeric variable, and imputing with the median is preferable over the mean because the median is less affected by outliers. This approach preserves the distribution of loan amounts without skewing the data.
#    - **Code**:
#      ```python
#      data['LoanAmount'].fillna(data['LoanAmount'].median(), inplace=True)
#      ```
#
# ### 5. **Loan_Amount_Term (6 missing values)**:
#    - **Approach**: Impute with the most frequent value (mode).
#    - **Reasoning**: Loan_Amount_Term is a numeric variable but typically takes on discrete values (e.g., 360 months, 180 months). Imputing with the mode (most common loan term) is appropriate since it aligns with the majority of the data.
#    - **Code**:
#      ```python
#      data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace=True)
#      ```
#
# ### 6. **Credit_History (29 missing values)**:
#    - **Approach**: Impute with the most frequent value (mode).
#    - **Reasoning**: Credit_History is a binary variable (1 for good credit, 0 for bad credit). Since credit history is crucial in determining loan eligibility, imputing with the mode (likely 1) minimizes the risk of introducing bias while leveraging the most common outcome.
#    - **Code**:
#      ```python
#      data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)
#      ```
#
# ### Summary of Approaches:
# - **Mode Imputation**: Used for categorical variables like `Gender`, `Dependents`, `Self_Employed`, `Loan_Amount_Term`, and `Credit_History` because it preserves the original distribution of the data.
# - **Median Imputation**: Used for `LoanAmount` because it reduces the impact of outliers and is more robust than the mean.
#
# These approaches balance the need to retain as much data as possible with the goal of minimizing the introduction of bias. By imputing missing values rather than dropping them, you maintain the dataset's size and integrity, which is especially important if the missing data is relatively small.

# %%
# First, let's handle the missing values for the dataset.
# For categorical columns, we'll use mode imputation, and for numerical columns, we'll use mean imputation.

# Impute missing values for categorical columns using mode
categorical_cols = ['Gender', 'Dependents', 'Self_Employed']
for col in categorical_cols:
    data[col].fillna(data[col].mode()[0], inplace=True)

# Impute missing values for numerical columns using mean
numerical_cols = ['LoanAmount', 'Loan_Amount_Term', 'Credit_History']
for col in numerical_cols:
    data[col].fillna(data[col].mean(), inplace=True)

# Check if all missing values have been handled
missing_values_after_imputation = data.isnull().sum()

missing_values_after_imputation
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
data
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for plots
sns.set(style="whitegrid")

# Univariate Analysis: Histograms for numeric columns
numeric_cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

# Plot histograms
plt.figure(figsize=(15, 5))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(1, 3, i)
    sns.histplot(data[col], kde=True)
    plt.title(f'Histogram of {col}')

plt.tight_layout()
plt.show()

# Univariate Analysis: Box Plots for numeric columns
plt.figure(figsize=(15, 5))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(data[col])
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# Univariate Analysis: Bar Charts for categorical columns
categorical_cols = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area']

plt.figure(figsize=(18, 10))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(2, 3, i)
    sns.countplot(x=col, data=data)
    plt.title(f'Bar Chart of {col}')

plt.tight_layout()
plt.show()

# Univariate Analysis: Pie Charts for categorical columns
plt.figure(figsize=(18, 10))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(2, 3, i)
    data[col].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
    plt.title(f'Pie Chart of {col}')
    plt.ylabel('')

plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Bivariate Analysis: Scatter plots for numeric columns
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.scatterplot(x='ApplicantIncome', y='LoanAmount', data=data)
plt.title('Applicant Income vs Loan Amount')

plt.subplot(1, 3, 2)
sns.scatterplot(x='CoapplicantIncome', y='LoanAmount', data=data)
plt.title('Coapplicant Income vs Loan Amount')

plt.subplot(1, 3, 3)
sns.scatterplot(x='ApplicantIncome', y='CoapplicantIncome', data=data)
plt.title('Applicant Income vs Coapplicant Income')

plt.tight_layout()
plt.show()

# Pair plot to visualize interactions between multiple numeric variables
sns.pairplot(data[numeric_cols])
plt.show()

# Bivariate Analysis: Box plots for categorical vs numeric
plt.figure(figsize=(18, 8))
for i, col in enumerate(categorical_cols[:3], 1):
    plt.subplot(1, 3, i)
    sns.boxplot(x=col, y='LoanAmount', data=data)
    plt.title(f'Loan Amount by {col}')

plt.tight_layout()
plt.show()

# Violin plots for categorical vs numeric variables
plt.figure(figsize=(18, 8))
for i, col in enumerate(categorical_cols[3:], 1):
    plt.subplot(1, 3, i)
    sns.violinplot(x=col, y='LoanAmount', data=data)
    plt.title(f'Loan Amount by {col}')

plt.tight_layout()
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(x='ApplicantIncome', y='LoanAmount', data=data)
sns.scatterplot(x='CoapplicantIncome', y='LoanAmount', data=data)
sns.scatterplot(x='ApplicantIncome', y='CoapplicantIncome', data=data)
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.pairplot(data[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(x='Gender', y='LoanAmount', data=data)
sns.boxplot(x='Married', y='LoanAmount', data=data)
sns.boxplot(x='Education', y='LoanAmount', data=data)
# Out:
# <Axes: xlabel='Education', ylabel='LoanAmount'>

# %%
sns.violinplot(x='Self_Employed', y='LoanAmount', data=data)
sns.violinplot(x='Property_Area', y='LoanAmount', data=data)
# Out:
# <Axes: xlabel='Property_Area', ylabel='LoanAmount'>

# %%
# Select only numeric columns
numeric_data = data.select_dtypes(include=['int64', 'float64'])

# Calculate correlation matrix
corr = numeric_data.corr()

# Plot heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
pd.crosstab(data['Property_Area'], data['Married']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Property_Area'>
